# %% [markdown]
# ## Working on Jsons

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get(url='http://citibikenyc.com/stations/json')
json_readed = r.json()

# %%
print(json_readed)
# Out:
# 'longitude': -73.90951, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 2, 'stAddress1': 'Central Ave & Covert St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 03:52:56 AM', 'landMark': ''}, {'id': 3865, 'stationName': 'Knickerbocker Ave & Cooper St', 'availableDocks': 19, 'totalDocks': 24, 'latitude': 40.69081, 'longitude': -73.90448, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 5, 'stAddress1': 'Knickerbocker Ave & Cooper St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 03:55:28 AM', 'landMark': ''}, {'id': 3866, 'stationName': 'Wilson Ave & Moffat St', 'availableDocks': 29, 'totalDocks': 32, 'latitude': 40.68906, 'longitude': -73.90506, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 3, 'stAddress1': 'Wilson Ave & Moffat St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 03:52:29 AM', 'landMark': ''}, {'id': 3867, 'stationName': 'Somers St & Broadway', 'availableDocks': 28, 'totalDocks': 29, 'latitude': 40.67945, 'longitude': -73.90474, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 1, 'stAddress1': 'Somers St & Broadway', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 03:51:43 AM', 'landMark': ''}, {'id': 3868, 'stationName': 'Knickerbocker Ave & Halsey St', 'availableDocks': 18, 'totalDocks': 19, 'latitude': 40.693, 'longitude': -73.90824, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 1, 'stAddress1': 'Knickerbocker Ave & Halsey St', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 03:55:28 AM', 'landMark': ''}, {'id': 3869, 'stationName': 'Van Buren St & Broadway', 'availableDocks': 22, 'totalDocks': 24, 'latitude': 40.692, 'longitude': -73.92617, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 2, 'stAddress1': 'Van Buren St & Broadway', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 03:53:09 AM', 'landMark': ''}, {'id': 3870, 'stationName': 'Melrose St & Broadway', 'availableDocks': 19, 'totalDocks': 20, 'latitude': 40.697481, 'longitude': -73.935877, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 1, 'stAddress1': 'Melrose St & Broadway', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 03:53:29 AM', 'landMark': ''}, {'id': 3871, 'stationName': 'Bushwick Ave & Furman Ave', 'availableDocks': 27, 'totalDocks': 30, 'latitude': 40.68281, 'longitude': -73.90623, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 3, 'stAddress1': 'Bushwick Ave & Furman Ave', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 03:53:49 AM', 'landMark': ''}, {'id': 3872, 'stationName': 'Hancock St & Wyckoff Ave', 'availableDocks': 19, 'totalDocks': 19, 'latitude': 40.6972, 'longitude': -73.90674, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 0, 'stAddress1': 'Hancock St & Wyckoff Ave', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStation': False, 'lastCommunicationTime': '2020-03-11 03:54:09 AM', 'landMark': ''}, {'id': 3873, 'stationName': 'Madison St & Cypress Ave', 'availableDocks': 13, 'totalDocks': 17, 'latitude': 40.70068, 'longitude': -73.90742, 'statusValue': 'In Service', 'statusKey': 1, 'availableBikes': 4, 'stAddress1': 'Madison St & Cypress Ave', 'stAddress2': '', 'city': '', 'postalCode': '', 'location': '', 'altitude': '', 'testStati ...

# %% [markdown]
# Save json in a local file called "data.json"

# %%
with open('data.json', 'w+') as outfile:
    json.dump(json_readed, outfile)

# %%
with open('data.json') as f:
    line = f.readline()
    if line:
        print(line)
        line = f.readline()
print(line)
# Out:
# longitude": -73.90951, "statusValue": "In Service", "statusKey": 1, "availableBikes": 2, "stAddress1": "Central Ave & Covert St", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 03:52:56 AM", "landMark": ""}, {"id": 3865, "stationName": "Knickerbocker Ave & Cooper St", "availableDocks": 19, "totalDocks": 24, "latitude": 40.69081, "longitude": -73.90448, "statusValue": "In Service", "statusKey": 1, "availableBikes": 5, "stAddress1": "Knickerbocker Ave & Cooper St", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 03:55:28 AM", "landMark": ""}, {"id": 3866, "stationName": "Wilson Ave & Moffat St", "availableDocks": 29, "totalDocks": 32, "latitude": 40.68906, "longitude": -73.90506, "statusValue": "In Service", "statusKey": 1, "availableBikes": 3, "stAddress1": "Wilson Ave & Moffat St", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 03:52:29 AM", "landMark": ""}, {"id": 3867, "stationName": "Somers St & Broadway", "availableDocks": 28, "totalDocks": 29, "latitude": 40.67945, "longitude": -73.90474, "statusValue": "In Service", "statusKey": 1, "availableBikes": 1, "stAddress1": "Somers St & Broadway", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 03:51:43 AM", "landMark": ""}, {"id": 3868, "stationName": "Knickerbocker Ave & Halsey St", "availableDocks": 18, "totalDocks": 19, "latitude": 40.693, "longitude": -73.90824, "statusValue": "In Service", "statusKey": 1, "availableBikes": 1, "stAddress1": "Knickerbocker Ave & Halsey St", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 03:55:28 AM", "landMark": ""}, {"id": 3869, "stationName": "Van Buren St & Broadway", "availableDocks": 22, "totalDocks": 24, "latitude": 40.692, "longitude": -73.92617, "statusValue": "In Service", "statusKey": 1, "availableBikes": 2, "stAddress1": "Van Buren St & Broadway", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 03:53:09 AM", "landMark": ""}, {"id": 3870, "stationName": "Melrose St & Broadway", "availableDocks": 19, "totalDocks": 20, "latitude": 40.697481, "longitude": -73.935877, "statusValue": "In Service", "statusKey": 1, "availableBikes": 1, "stAddress1": "Melrose St & Broadway", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 03:53:29 AM", "landMark": ""}, {"id": 3871, "stationName": "Bushwick Ave & Furman Ave", "availableDocks": 27, "totalDocks": 30, "latitude": 40.68281, "longitude": -73.90623, "statusValue": "In Service", "statusKey": 1, "availableBikes": 3, "stAddress1": "Bushwick Ave & Furman Ave", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 03:53:49 AM", "landMark": ""}, {"id": 3872, "stationName": "Hancock St & Wyckoff Ave", "availableDocks": 19, "totalDocks": 19, "latitude": 40.6972, "longitude": -73.90674, "statusValue": "In Service", "statusKey": 1, "availableBikes": 0, "stAddress1": "Hancock St & Wyckoff Ave", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStation": false, "lastCommunicationTime": "2020-03-11 03:54:09 AM", "landMark": ""}, {"id": 3873, "stationName": "Madison St & Cypress Ave", "availableDocks": 13, "totalDocks": 17, "latitude": 40.70068, "longitude": -73.90742, "statusValue": "In Service", "statusKey": 1, "availableBikes": 4, "stAddress1": "Madison St & Cypress Ave", "stAddress2": "", "city": "", "postalCode": "", "location": "", "altitude": "", "testStatio ...

# %% [markdown]
# Save with indent

# %%
with open('data_indented.json', 'w+') as outfile:
    json.dump(json_readed, outfile, indent=4)

# %% [markdown]
# Read local json

# %%
with open('data_indented.json', 'r+') as outfile:
    json_readed = json.load(outfile)
json_readed
# Out:
# 2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:18:35 AM',
#    'landMark': ''},
#   {'id': 3870,
#    'stationName': 'Melrose St & Broadway',
#    'availableDocks': 20,
#    'totalDocks': 20,
#    'latitude': 40.697481,
#    'longitude': -73.935877,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Melrose St & Broadway',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:20:56 AM',
#    'landMark': ''},
#   {'id': 3871,
#    'stationName': 'Bushwick Ave & Furman Ave',
#    'availableDocks': 29,
#    'totalDocks': 30,
#    'latitude': 40.68281,
#    'longitude': -73.90623,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Bushwick Ave & Furman Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:37 AM',
#    'landMark': ''},
#   {'id': 3872,
#    'stationName': 'Hancock St & Wyckoff Ave',
#    'availableDocks': 19,
#    'totalDocks': 19,
#    'latitude': 40.6972,
#    'longitude': -73.90674,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Hancock St & Wyckoff Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:01 AM',
#    'landMark': ''},
#   {'id': 3873,
#    'stationName': 'Madison St & Cypress Ave',
#    'availableDocks': 17,
#    'totalDocks': 17,
#    'latitude': 40.70068,
#    'longitude': -73.90742,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Madison St & Cypress Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:54 AM',
#    'landMark': ''},
#   {'id': 3874,
#    'stationName': 'Menahan St & Seneca Ave',
#    'availableDocks': 15,
#    'totalDocks': 16,
#    'latitude': 40.70461,
#    'longitude': -73.91054,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Menahan St & Seneca Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:04 AM',
#    'landMark': ''},
#   {'id': 3875,
#    'stationName': 'Stephen St & Seneca Ave',
#    'availableDocks': 15,
#    'totalDocks': 15,
#    'latitude': 40.6988,
#    'longitude': -73.9007,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Stephen St & Seneca Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:18 AM',
#    'landMark': ''},
#   {'id': 3876,
#    'stationName': 'Forest Ave & Summerfield St',
#    'availableDocks': 19,
#    'totalDocks': 23,
#    'latitude': 40.69922,
#    'longitude': -73.89795,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Forest Ave & Summerfield St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:39 AM',
#    'landMark': ''},
#   {'id': 3877,
#    'stationName': 'Madison St & Forest Ave',
#    'availableDocks': 24,
#    'totalDocks': 25,
#    'latitude': 40.70555,
#    'longitude': -73.90245,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Madison St & Forest Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:18:56 AM',
#    'landMark': ''},
#   {'id': 3878,
#    'stationName': 'Cypress Ave & George St',
#    'availableDocks': 16,
#    'totalDocks': 19,
#    'latitude': 40.69812,
#    'longitude': -73.90271,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Cypress Ave & George St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:20:57 AM',
#    'landMark': ''},
#   {'id': 3879,
#    'stationName': 'Broadway & Madison St',
#    'availableDocks': 20,
#    'totalDocks': 25,
#    'latitude': 40.68822,
#    'longitude': -73.91966,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'Broadway & Madison St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:20:17 AM',
#    'landMark': ''},
#   {'id': 3880,
#    'stationName': 'Willoughby Ave & Onderdonk Ave',
#    'availableDocks': 26,
#    'totalDocks': 27,
#    'latitude': 40.7098,
#    'longitude': -73.91727,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Willoughby Ave & Onderdonk Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:18:44 AM',
#    'landMark': ''},
#   {'id': 3881,
#    'stationName': '12 Ave & W 125 St',
#    'availableDocks': 6,
#    'totalDocks': 39,
#    'latitude': 40.818299,
#    'longitude': -73.960405,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 33,
#    'stAddress1': '12 Ave & W 125 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:21 AM',
#    'landMark': ''},
#   {'id': 3882,
#    'stationName': 'Norman St & Wyckoff Ave',
#    'availableDocks': 14,
#    'totalDocks': 15,
#    'latitude': 40.69517,
#    'longitude': -73.90311,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Norman St & Wyckoff Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:18:01 AM',
#    'landMark': ''},
#   {'id': 3883,
#    'stationName': 'Harman St & Seneca Ave',
#    'availableDocks': 16,
#    'totalDocks': 19,
#    'latitude': 40.70577,
#    'longitude': -73.91292,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Harman St & Seneca Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:20:02 AM',
#    'landMark': ''},
#   {'id': 3884,
#    'stationName': 'Centre St & Seneca Ave',
#    'availableDocks': 23,
#    'totalDocks': 23,
#    'latitude': 40.69969,
#    'longitude': -73.9022,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Centre St & Seneca Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:18:19 AM',
#    'landMark': ''},
#   {'id': 3885,
#    'stationName': 'Onderdonk Ave & Gates Ave',
#    'availableDocks': 16,
#    'totalDocks': 19,
#    'latitude': 40.70413,
#    'longitude': -73.90737,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Onderdonk Ave & Gates Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:20:53 AM',
#    'landMark': ''},
#   {'id': 3886,
#    'stationName': 'Menahan St & Onderdonk Ave',
#    'availableDocks': 17,
#    'totalDocks': 20,
#    'latitude': 40.70553,
#    'longitude': -73.9096,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Menahan St & Onderdonk Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:18:16 AM',
#    'landMark': ''},
#   {'id': 3887,
#    'stationName': 'Flushing Ave & Woodward Ave',
#    'availableDocks': 13,
#    'totalDocks': 21,
#    'latitude': 40.71246,
#    'longitude': -73.91873,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 7,
#    'stAddress1': 'Flushing Ave & Woodward Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:18:20 AM',
#    'landMark': ''},
#   {'id': 3888,
#    'stationName': 'Woodward Ave & Harman St',
#    'availableDocks': 17,
#    'totalDocks': 19,
#    'latitude': 40.70793,
#    'longitude': -73.91092,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Woodward Ave & Harman St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:10 AM',
#    'landMark': ''},
#   {'id': 3890,
#    'stationName': 'Grove St & Broadway',
#    'availableDocks': 29,
#    'totalDocks': 31,
#    'latitude': 40.69047,
#    'longitude': -73.923511,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Grove St & Broadway',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:03 AM',
#    'landMark': ''},
#   {'id': 3891,
#    'stationName': 'Irving Ave & Palmetto St',
#    'availableDocks': 18,
#    'totalDocks': 20,
#    'latitude': 40.698,
#    'longitude': -73.9127,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Irving Ave & Palmetto St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:47 AM',
#    'landMark': ''},
#   {'id': 3892,
#    'stationName': '38 Ave & 29 St',
#    'availableDocks': 19,
#    'totalDocks': 19,
#    'latitude': 40.75473,
#    'longitude': -73.93367,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': '38 Ave & 29 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:10 AM',
#    'landMark': ''},
#   {'id': 3893,
#    'stationName': 'Rockaway Ave & Bainbridge St',
#    'availableDocks': 16,
#    'totalDocks': 25,
#    'latitude': 40.68319988172761,
#    'longitude': -73.91166642308235,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 8,
#    'stAddress1': 'Rockaway Ave & Bainbridge St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:18:48 AM',
#    'landMark': ''},
#   {'id': 3895,
#    'stationName': 'Cypress Ave & Palmetto St',
#    'availableDocks': 21,
#    'totalDocks': 25,
#    'latitude': 40.701573408737914,
#    'longitude': -73.90876293182373,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Cypress Ave & Palmetto St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:07 AM',
#    'landMark': ''},
#   {'id': 3896,
#    'stationName': 'Madison St & Seneca Ave',
#    'availableDocks': 19,
#    'totalDocks': 22,
#    'latitude': 40.70183,
#    'longitude': -73.90625,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Madison St & Seneca Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:44 AM',
#    'landMark': ''},
#   {'id': 3897,
#    'stationName': 'Onderdonk Ave & Dekalb Ave',
#    'availableDocks': 16,
#    'totalDocks': 17,
#    'latitude': 40.70863,
#    'longitude': -73.91497,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Onderdonk Ave & Dekalb Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:44 AM',
#    'landMark': ''},
#   {'id': 3898,
#    'stationName': 'E 63 St & 3 Ave',
#    'availableDocks': 53,
#    'totalDocks': 57,
#    'latitude': 40.763954,
#    'longitude': -73.9646,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'E 63 St & 3 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:03 AM',
#    'landMark': ''},
#   {'id': 3899,
#    'stationName': 'Manhattan Av & Leonard St',
#    'availableDocks': 14,
#    'totalDocks': 18,
#    'latitude': 40.72084,
#    'longitude': -73.94844,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Manhattan Av & Leonard St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:11 AM',
#    'landMark': ''},
#   {'id': 3900,
#    'stationName': 'Morgan Ave & Lombardy St',
#    'availableDocks': 30,
#    'totalDocks': 30,
#    'latitude': 40.72226,
#    'longitude': -73.93889,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Morgan Ave & Lombardy St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:44 AM',
#    'landMark': ''},
#   {'id': 3901,
#    'stationName': 'Stanhope St & Fairview Ave',
#    'availableDocks': 14,
#    'totalDocks': 17,
#    'latitude': 40.70998,
#    'longitude': -73.91116,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Stanhope St & Fairview Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:58 AM',
#    'landMark': ''},
#   {'id': 3902,
#    'stationName': 'Fairview Ave & Linden St',
#    'availableDocks': 17,
#    'totalDocks': 19,
#    'latitude': 40.70694,
#    'longitude': -73.90632,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Fairview Ave & Linden St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:49 AM',
#    'landMark': ''},
#   {'id': 3903,
#    'stationName': 'Jefferson Ave & Evergreen Ave',
#    'availableDocks': 16,
#    'totalDocks': 17,
#    'latitude': 40.68989,
#    'longitude': -73.91458,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Jefferson Ave & Evergreen Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:18:20 AM',
#    'landMark': ''},
#   {'id': 3905,
#    'stationName': '4 Ave & E 12 St',
#    'availableDocks': 3,
#    'totalDocks': 27,
#    'latitude': 40.732647,
#    'longitude': -73.99011,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 22,
#    'stAddress1': '4 Ave & E 12 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:33 AM',
#    'landMark': ''},
#   {'id': 3907,
#    'stationName': 'Central Ave & Melrose St',
#    'availableDocks': 17,
#    'totalDocks': 17,
#    'latitude': 40.70112,
#    'longitude': -73.93039,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Central Ave & Melrose St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:43 AM',
#    'landMark': ''},
#   {'id': 3909,
#    'stationName': 'Madison St & Woodward Ave',
#    'availableDocks': 18,
#    'totalDocks': 20,
#    'latitude': 40.70408,
#    'longitude': -73.90408,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Madison St & Woodward Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:37 AM',
#    'landMark': ''},
#   {'id': 3910,
#    'stationName': 'Greene Ave & Grandview Ave',
#    'availableDocks': 15,
#    'totalDocks': 17,
#    'latitude': 40.709697,
#    'longitude': -73.907856,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Greene Ave & Grandview Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:37 AM',
#    'landMark': ''},
#   {'id': 3911,
#    'stationName': 'Wyckoff St & Nevins St',
#    'availableDocks': 9,
#    'totalDocks': 22,
#    'latitude': 40.683426,
#    'longitude': -73.984275,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 13,
#    'stAddress1': 'Wyckoff St & Nevins St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:18:52 AM',
#    'landMark': ''},
#   {'id': 3913,
#    'stationName': 'Sands St Gate',
#    'availableDocks': 9,
#    'totalDocks': 19,
#    'latitude': 40.699569,
#    'longitude': -73.979827,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 9,
#    'stAddress1': 'Sands St Gate',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:37 AM',
#    'landMark': ''},
#   {'id': 3914,
#    'stationName': 'West End Ave & W 78 St',
#    'availableDocks': 27,
#    'totalDocks': 39,
#    'latitude': 40.783786,
#    'longitude': -73.981687,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 11,
#    'stAddress1': 'West End Ave & W 78 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:16:53 AM',
#    'landMark': ''},
#   {'id': 3916,
#    'stationName': 'Pearl St & Peck Slip',
#    'availableDocks': 2,
#    'totalDocks': 45,
#    'latitude': 40.708485,
#    'longitude': -74.002751,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 43,
#    'stAddress1': 'Pearl St & Peck Slip',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:20 AM',
#    'landMark': ''},
#   {'id': 3917,
#    'stationName': 'Willoughby St & Ashland Pl',
#    'availableDocks': 28,
#    'totalDocks': 31,
#    'latitude': 40.69178,
#    'longitude': -73.97877,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Willoughby St & Ashland Pl',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:17:54 AM',
#    'landMark': ''},
#   {'id': 3918,
#    'stationName': 'Avenue D & E 8 St',
#    'availableDocks': 0,
#    'totalDocks': 30,
#    'latitude': 40.72387,
#    'longitude': -73.975767,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 30,
#    'stAddress1': 'Avenue D & E 8 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2020-03-03 04:19:54 AM',
#    'landMark': ''}]}

# %%
df_json = pd.read_json("data_indented.json")
df_json
# Out:
#               executionTime                                    stationBeanList
# 0    2020-03-11 03:55:31 AM  {'id': 304, 'stationName': 'Broadway & Battery...
# 1    2020-03-11 03:55:31 AM  {'id': 3255, 'stationName': '8 Ave & W 31 St',...
# 2    2020-03-11 03:55:31 AM  {'id': 72, 'stationName': 'W 52 St & 11 Ave', ...
# 3    2020-03-11 03:55:31 AM  {'id': 79, 'stationName': 'Franklin St & W Bro...
# 4    2020-03-11 03:55:31 AM  {'id': 82, 'stationName': 'St James Pl & Pearl...
# ..                      ...                                                ...
# 930  2020-03-11 03:55:31 AM  {'id': 3913, 'stationName': 'Sands St Gate', '...
# 931  2020-03-11 03:55:31 AM  {'id': 3914, 'stationName': 'West End Ave & W ...
# 932  2020-03-11 03:55:31 AM  {'id': 3916, 'stationName': 'Pearl St & Peck S...
# 933  2020-03-11 03:55:31 AM  {'id': 3917, 'stationName': 'Willoughby St & A...
# 934  2020-03-11 03:55:31 AM  {'id': 3918, 'stationName': 'Avenue D & E 8 St...
#
# [935 rows x 2 columns]

# %%
df_json = df_json.set_index("executionTime")
df_json
# Out:
#                                                           stationBeanList
# executionTime
# 2020-03-11 03:55:31 AM  {'id': 304, 'stationName': 'Broadway & Battery...
# 2020-03-11 03:55:31 AM  {'id': 3255, 'stationName': '8 Ave & W 31 St',...
# 2020-03-11 03:55:31 AM  {'id': 72, 'stationName': 'W 52 St & 11 Ave', ...
# 2020-03-11 03:55:31 AM  {'id': 79, 'stationName': 'Franklin St & W Bro...
# 2020-03-11 03:55:31 AM  {'id': 82, 'stationName': 'St James Pl & Pearl...
# ...                                                                   ...
# 2020-03-11 03:55:31 AM  {'id': 3913, 'stationName': 'Sands St Gate', '...
# 2020-03-11 03:55:31 AM  {'id': 3914, 'stationName': 'West End Ave & W ...
# 2020-03-11 03:55:31 AM  {'id': 3916, 'stationName': 'Pearl St & Peck S...
# 2020-03-11 03:55:31 AM  {'id': 3917, 'stationName': 'Willoughby St & A...
# 2020-03-11 03:55:31 AM  {'id': 3918, 'stationName': 'Avenue D & E 8 St...
#
# [935 rows x 1 columns]

# %%
df_json["stationBeanList"].values[0]
# Out:
# {'id': 304,
#  'stationName': 'Broadway & Battery Pl',
#  'availableDocks': 11,
#  'totalDocks': 33,
#  'latitude': 40.70463334,
#  'longitude': -74.01361706,
#  'statusValue': 'In Service',
#  'statusKey': 1,
#  'availableBikes': 21,
#  'stAddress1': 'Broadway & Battery Pl',
#  'stAddress2': '',
#  'city': '',
#  'postalCode': '',
#  'location': '',
#  'altitude': '',
#  'testStation': False,
#  'lastCommunicationTime': '2020-03-11 03:53:37 AM',
#  'landMark': ''}

# %%
df_json2 = pd.read_json("http://citibikenyc.com/stations/json")
df_json2
# Out:
#               executionTime                                    stationBeanList
# 0    2020-03-11 04:04:41 AM  {'id': 304, 'stationName': 'Broadway & Battery...
# 1    2020-03-11 04:04:41 AM  {'id': 3255, 'stationName': '8 Ave & W 31 St',...
# 2    2020-03-11 04:04:41 AM  {'id': 72, 'stationName': 'W 52 St & 11 Ave', ...
# 3    2020-03-11 04:04:41 AM  {'id': 79, 'stationName': 'Franklin St & W Bro...
# 4    2020-03-11 04:04:41 AM  {'id': 82, 'stationName': 'St James Pl & Pearl...
# ..                      ...                                                ...
# 930  2020-03-11 04:04:41 AM  {'id': 3913, 'stationName': 'Sands St Gate', '...
# 931  2020-03-11 04:04:41 AM  {'id': 3914, 'stationName': 'West End Ave & W ...
# 932  2020-03-11 04:04:41 AM  {'id': 3916, 'stationName': 'Pearl St & Peck S...
# 933  2020-03-11 04:04:41 AM  {'id': 3917, 'stationName': 'Willoughby St & A...
# 934  2020-03-11 04:04:41 AM  {'id': 3918, 'stationName': 'Avenue D & E 8 St...
#
# [935 rows x 2 columns]

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are jsons inside the original json. For that, we have to mining the json (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

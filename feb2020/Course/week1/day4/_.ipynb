# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
url_infected = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv"

url_deaths = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv"

# %%
df_infected = pd.read_csv(url_infected)

# %%
df_infected
# Out:
#               Province/State  Country/Region      Lat      Long  1/22/20  \
# 0                      Anhui  Mainland China  31.8257  117.2264        1
# 1                    Beijing  Mainland China  40.1824  116.4142       14
# 2                  Chongqing  Mainland China  30.0572  107.8740        6
# 3                     Fujian  Mainland China  26.0789  117.9874        1
# 4                      Gansu  Mainland China  36.0611  103.8343        0
# ..                       ...             ...      ...       ...      ...
# 155                      NaN       Gibraltar  36.1408   -5.3536        0
# 156                      NaN   Liechtenstein  47.1400    9.5500        0
# 157                      NaN          Poland  51.9194   19.1451        0
# 158                      NaN         Tunisia  34.0000    9.0000        0
# 159  Contra Costa County, CA              US  37.8534 -121.9018        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/24/20  2/25/20  \
# 0          9       15       39       60       70  ...      989      989
# 1         22       36       41       68       80  ...      399      400
# 2          9       27       57       75      110  ...      576      576
# 3          5       10       18       35       59  ...      293      294
# 4          2        2        4        7       14  ...       91       91
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 155        0        0        0        0        0  ...        0        0
# 156        0        0        0        0        0  ...        0        0
# 157        0        0        0        0        0  ...        0        0
# 158        0        0        0        0        0  ...        0        0
# 159        0        0        0        0        0  ...        0        0
#
#      2/26/20  2/27/20  2/28/20  2/29/20  3/1/20  3/2/20  3/3/20  3/4/20
# 0        989      989      990      990     990     990     990     990
# 1        400      410      410      411     413     414     414     418
# 2        576      576      576      576     576     576     576     576
# 3        294      296      296      296     296     296     296     296
# 4         91       91       91       91      91      91      91      91
# ..       ...      ...      ...      ...     ...     ...     ...     ...
# 155        0        0        0        0       0       0       0       1
# 156        0        0        0        0       0       0       0       1
# 157        0        0        0        0       0       0       0       1
# 158        0        0        0        0       0       0       0       1
# 159        0        0        0        0       0       0       0       1
#
# [160 rows x 47 columns]

# %%
df_infected.plot()
